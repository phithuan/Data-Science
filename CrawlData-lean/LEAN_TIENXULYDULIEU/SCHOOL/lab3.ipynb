# %%
import requests 
from bs4 import BeautifulSoup 
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 
import os
import csv
import re
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\Admin\Desktop\GKD\Data-science-GitHub\CRAWL_DATA_LEAN\venv\LEAN_TIENXULYDULIEU\SCHOOL\lab3.ipynb Cell 1 line 1
#       <a href='vscode-notebook-cell:/c%3A/Users/Admin/Desktop/GKD/Data-science-GitHub/CRAWL_DATA_LEAN/venv/LEAN_TIENXULYDULIEU/SCHOOL/lab3.ipynb#W0sZmlsZQ%3D%3D?line=8'>9</a> import re
#      <a href='vscode-notebook-cell:/c%3A/Users/Admin/Desktop/GKD/Data-science-GitHub/CRAWL_DATA_LEAN/venv/LEAN_TIENXULYDULIEU/SCHOOL/lab3.ipynb#W0sZmlsZQ%3D%3D?line=9'>10</a> import os
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Admin/Desktop/GKD/Data-science-GitHub/CRAWL_DATA_LEAN/venv/LEAN_TIENXULYDULIEU/SCHOOL/lab3.ipynb#W0sZmlsZQ%3D%3D?line=10'>11</a> import cv2
# ...

# %%
seed_urls = ['https://notes.ayushsharma.in/technology',
             'https://www.ayush.nz/video-games']

# %%
response = requests.get(seed_urls[0])# Gửi yêu cầu GET đến trang web và lấy nội dung đầu tiên
print(response)
# Out:
# <Response [200]>

# %%
response1 = requests.get(seed_urls[1])# Gửi yêu cầu GET đến trang web và lấy nội dung đầu tiên
print(response1)
# Out:
# <Response [200]>

# %%
"""import requests
from bs4 import BeautifulSoup
import pandas as pd

seed_urls = [
    'https://notes.ayushsharma.in/technology',
    'https://www.ayush.nz/video-games'
]

def build_dataset(seed_urls):
    news_data = []
    for url in seed_urls:
        news_category = url.split('/')[-1]
        data = requests.get(url)
        soup = BeautifulSoup(data.content, 'html.parser')
        tables = soup.find_all('div',class_= 'col')
        for id, i in enumerate(tables):
            title = i.find_all('h5',class_='card-title')
            excerpt = i.find_all('small', class_ = 'card-text')
            pub_date = i.find_all('div', class_ = 'card-footer text-end')
            if title and excerpt and pub_date:
                title_position = title[0].text.strip()
                excerpt_position = excerpt[0].text.strip()
                date_published = pub_date[0].text.strip()
                news_data.append([title_position, excerpt_position, date_published, news_category])
        df = pd.DataFrame(news_data,columns=['title', 'excerpt', 'pub_date', 'category'])
    return df

# Gọi hàm để lấy dữ liệu
df = build_dataset(seed_urls)


# Lưu dữ liệu thành file CSV
df.to_csv('dataset3.csv', index=False)"""
# Out:
# "import requests\nfrom bs4 import BeautifulSoup\nimport pandas as pd\n\nseed_urls = [\n    'https://notes.ayushsharma.in/technology',\n    'https://www.ayush.nz/video-games'\n]\n\ndef build_dataset(seed_urls):\n    news_data = []\n    for url in seed_urls:\n        news_category = url.split('/')[-1]\n        data = requests.get(url)\n        soup = BeautifulSoup(data.content, 'html.parser')\n        tables = soup.find_all('div',class_= 'col')\n        for id, i in enumerate(tables):\n            title = i.find_all('h5',class_='card-title')\n            excerpt = i.find_all('small', class_ = 'card-text')\n            pub_date = i.find_all('div', class_ = 'card-footer text-end')\n            if title and excerpt and pub_date:\n                title_position = title[0].text.strip()\n                excerpt_position = excerpt[0].text.strip()\n                date_published = pub_date[0].text.strip()\n                news_data.append([title_position, excerpt_position, date_published, news
# ...

# %%
url = requests.get('https://notes.ayushsharma.in/technology',
                   'https://www.ayush.nz/video-games')
soup = BeautifulSoup(url.text, "html.parser")

# %%
title = soup.find_all('h5', {'class':'card-title'})
print(title)
# Out:
# [<h5 class="card-title">Consuming APIs responsibly</h5>, <h5 class="card-title">Create a series of posts with navigation in Jekyll</h5>, <h5 class="card-title">A practical guide to light and dark mode in Bootstrap 5 and Jekyll</h5>, <h5 class="card-title">Nemo - The Ubuntu file manager you didn’t know you needed</h5>, <h5 class="card-title">Announcing Fediverse.to!</h5>, <h5 class="card-title">Easy pretty URL redirects with Jekyll and Netlify</h5>, <h5 class="card-title">Linking Jekyll pages back to their Git source code</h5>, <h5 class="card-title">Optimising JPG and PNG images for a Jekyll website</h5>, <h5 class="card-title">Quick and easy client-side JavaScript search with Lunr.js</h5>, <h5 class="card-title">Creating light and dark themes for websites the right way using prefers-color-scheme</h5>, <h5 class="card-title">Make Linux apps for Notion, Mastodon, or any web app using Nativefier</h5>, <h5 class="card-title">Inserting dynamic data into Jekyll static sites using Python o
# ...

# %%
excerpt = soup.find_all('small', {'class':'card-text'})
print(excerpt)
# Out:
# [<small class="card-text">Or: Etiquette and table manners for pinging other people's servers.</small>, <small class="card-text">Add Jekyll posts into a series with series navigation.</small>, <small class="card-text">Implementing light and dark mode on your Bootstrap 5 + Jekyll website.</small>, <small class="card-text">Celebrate 2022 with a shiny new file manager for Ubuntu!</small>, <small class="card-text">I've been working on a search engine for Fediverse instances!</small>, <small class="card-text">Combine Jekyll and Netlify to create pretty URL redirects as easy as 1-2-3.</small>, <small class="card-text">Add a link back to the public Git hosting link for any static Jekyll blog.</small>, <small class="card-text">Use CLI tools to generate resized and optimised thumbnails for articles header images.</small>, <small class="card-text">Display search results from any JSON data object in the browser using Lunr.js.</small>, <small class="card-text">Blur the line between desktop and we
# ...

# %%
pub_date = soup.find_all(class_= "card-footer text-end")
print(pub_date)
# Out:
# [<div class="card-footer text-end">
# <small>Nov 2022</small>
# </div>, <div class="card-footer text-end">
# <small>Feb 2022</small>
# </div>, <div class="card-footer text-end">
# <small>Jan 2022</small>
# </div>, <div class="card-footer text-end">
# <small>Jan 2022</small>
# </div>, <div class="card-footer text-end">
# <small>Jan 2022</small>
# </div>, <div class="card-footer text-end">
# <small>Nov 2021</small>
# </div>, <div class="card-footer text-end">
# <small>Nov 2021</small>
# </div>, <div class="card-footer text-end">
# <small>Nov 2021</small>
# </div>, <div class="card-footer text-end">
# <small>Nov 2021</small>
# </div>, <div class="card-footer text-end">
# <small>Oct 2021</small>
# </div>, <div class="card-footer text-end">
# <small>Oct 2021</small>
# </div>, <div class="card-footer text-end">
# <small>Oct 2021</small>
# </div>, <div class="card-footer text-end">
# <small>Aug 2021</small>
# </div>, <div class="card-footer text-end">
# <small>Aug 2021</small>
# ...

# %%
# Tạo danh sách trống để chứa dữ liệu
data = []

# Lặp qua các URL và lấy dữ liệu từ mỗi URL
for url in seed_urls:
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Lấy dữ liệu từ trang web
    titles = soup.find_all('h5', {'class': 'card-title'})
    excerpts = soup.find_all('small', {'class': 'card-text'})
    pub_dates = soup.find_all(class_='card-footer text-end')
    
    # Thêm dữ liệu vào danh sách data
    """titles: Đây là danh sách (list) chứa các phần tử. Trong trường hợp của bạn, danh sách này chứa các thẻ HTML <h5> chứa các tiêu đề bài viết từ trang web.
    for title in titles: Đây là một vòng lặp for dùng để duyệt qua từng phần tử trong danh sách titles. Trong mỗi lần lặp, biến title sẽ trỏ đến một phần tử trong danh sách titles.
    title.text: Ở bên trong vòng lặp for, chúng ta sử dụng title (biến được đặt trong vòng lặp) để truy cập vào nội dung văn bản bên trong thẻ <h5>. Cụ thể, .text là thuộc tính để truy cập vào văn bản bên trong thẻ.
    title.text for title in titles: Toàn bộ biểu thức generator comprehension này tạo ra một danh sách mới, trong đó mỗi phần tử của danh sách mới chứa văn bản từ một thẻ <h5> trong danh sách titles."""
    data.append({
        'titles': [title.text for title in titles],
        'excerpts': [excerpt.text for excerpt in excerpts],
        'pub_dates': [date.text for date in pub_dates]
    })

# In dữ liệu
for item in data:
    for i in range(len(item['titles'])):
        print(f"Title: {item['titles'][i]}")
        print(f"Excerpt: {item['excerpts'][i]}")
        print(f"pub_date: {item['pub_dates'][i]}")
        print()
# Out:
# Title: Consuming APIs responsibly
# Excerpt: Or: Etiquette and table manners for pinging other people's servers.
# pub_date:
# Nov 2022
#
#
# Title: Create a series of posts with navigation in Jekyll
# Excerpt: Add Jekyll posts into a series with series navigation.
# pub_date:
# Feb 2022
#
#
# Title: A practical guide to light and dark mode in Bootstrap 5 and Jekyll
# Excerpt: Implementing light and dark mode on your Bootstrap 5 + Jekyll website.
# pub_date:
# Jan 2022
#
#
# Title: Nemo - The Ubuntu file manager you didn’t know you needed
# Excerpt: Celebrate 2022 with a shiny new file manager for Ubuntu!
# pub_date:
# Jan 2022
#
#
# Title: Announcing Fediverse.to!
# Excerpt: I've been working on a search engine for Fediverse instances!
# pub_date:
# Jan 2022
#
#
# Title: Easy pretty URL redirects with Jekyll and Netlify
# Excerpt: Combine Jekyll and Netlify to create pretty URL redirects as easy as 1-2-3.
# pub_date:
# Nov 2021
#
#
# ...

# %%
# Ghi dữ liệu vào file CSV
csv_file_path = 'dataset.csv'

with open(csv_file_path, 'w', newline='', encoding='utf-8') as csvfile:
    fieldnames = ['Title', 'Excerpt', 'Pub_Date']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

    # Viết header
    writer.writeheader()

    # Viết dữ liệu
    for item in data:
        for i in range(len(item['titles'])):
            writer.writerow({
                'Title': item['titles'][i],
                'Excerpt': item['excerpts'][i],
                'Pub_Date': item['pub_dates'][i]
            })

print(f"Dữ liệu đã được ghi vào file CSV: {csv_file_path}")
# Out:
# Dữ liệu đã được ghi vào file CSV: dataset.csv

# %%
import csv
import re

# Định nghĩa hàm để loại bỏ ký tự đặc biệt và chỉ lấy ngày tháng
def loai_bo_ky_tu_dac_biet_va_lay_ngay_thang(text):
    # Sử dụng biểu thức chính quy để tìm và lấy ngày tháng (định dạng MM/YYYY)
    match = re.search(r'\w+\s+(\d{4})', text)
    if match:
        return match.group(0)
    else:
        return ''

# Đọc dữ liệu từ tệp CSV
data = []
with open('dataset.csv', 'r', newline='', encoding='utf-8') as csvfile:
    csv_reader = csv.DictReader(csvfile)

    for row in csv_reader:
        # Loại bỏ ký tự đặc biệt và chỉ lấy ngày tháng
        row['Pub_Date'] = loai_bo_ky_tu_dac_biet_va_lay_ngay_thang(row['Pub_Date'])
        data.append(row)

# Ghi dữ liệu đã được xử lý vào một tệp CSV mới
with open('dataset1.csv', 'w', newline='', encoding='utf-8') as csvfile:
    fieldnames = ['Title', 'Excerpt', 'Pub_Date']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()
    writer.writerows(data)

print("Dữ liệu đã được xử lý và ghi vào file CSV mới: " + "dataset1")
# Out:
# Dữ liệu đã được xử lý và ghi vào file CSV mới: dataset1

# %% [markdown]
# # 3)  Loại bỏ ký tự có dấu

# %% [markdown]
# ####
# Hàm remove_diacritics trong trường hợp này được sử dụng để loại bỏ các dấu (ký tự có dấu) trong văn bản. Thường thì các ngôn ngữ sử dụng dấu để biểu thị âm điệu, ngữ điệu, và nhiều ngữ nghĩa khác, nhưng trong một số trường hợp, bạn có thể muốn loại bỏ dấu để đơn giản hóa văn bản hoặc để chuẩn hóa dữ liệu.
# Hàm remove_diacritics thường sử dụng thư viện hoặc module như unidecode để thực hiện việc loại bỏ dấu. Đây là cách nó hoạt động:
#
# Đầu vào của hàm remove_diacritics là một chuỗi văn bản có chứa các ký tự có dấu, chẳng hạn như "Mình yêu Việt Nam!".
#
# Hàm này sẽ sử dụng unidecode (hoặc tương tự) để chuyển chuỗi có dấu thành phiên bản không dấu. Trong trường hợp ví dụ trên, nó có thể trở thành "Minh yeu Viet Nam!".
#
# Kết quả của hàm remove_diacritics là chuỗi văn bản không có các ký tự có dấu. Điều này có thể hữu ích khi bạn muốn xử lý dữ liệu hoặc tìm kiếm trong văn bản mà không quan trọng đến việc có dấu hoặc không dấu.

# %%
import csv
from unidecode import unidecode

# Định nghĩa hàm để loại bỏ ký tự có dấu từ một chuỗi
def remove_diacritics(text):
    return unidecode(text)

# Đường dẫn đến tệp CSV nguồn
input_csv_file = 'dataset1.csv'

# Đường dẫn đến tệp CSV đích
output_csv_file = 'dataset3.csv'

# Mở tệp nguồn để đọc
with open(input_csv_file, mode='r', newline='') as input_file:
    reader = csv.reader(input_file)
    
    # Đọc dòng tiêu đề
    header = next(reader)
    
    # Mở tệp đích để ghi
    with open(output_csv_file, mode='w', newline='') as output_file:
        writer = csv.writer(output_file)
        
        # Ghi dòng tiêu đề
        writer.writerow(header)

        # Duyệt qua từng dòng dữ liệu trong tệp nguồn
        for row in reader:
            # Loại bỏ ký tự có dấu từ tất cả các cột
            cleaned_row = [remove_diacritics(cell) for cell in row]
    
            # Ghi dữ liệu đã xử lý vào tệp đích
            writer.writerow(cleaned_row)


print("Dữ liệu đã được xử lý và lưu vào tệp dataset3.csv.")
# Out:
# Dữ liệu đã được xử lý và lưu vào tệp dataset3.csv.

# %% [markdown]
# # 4)  Expand contractions

# %% [markdown]
# ####
# Hàm mo_rong_tu_viet_tat trong trường hợp này dường như là một hàm để mở rộng các từ viết tắt trong văn bản. Tên hàm "mo_rong_tu_viet_tat" trong tiếng Việt có thể được dịch là "expand_abbreviations" hoặc "mo_rong_tu_viet_tat" nếu bạn muốn giữ nguyên tên gốc.
#
# Cách hoạt động của hàm này là sử dụng một thư viện hoặc từ điển có sẵn (có thể là contractions) để tìm và thay thế các từ viết tắt trong văn bản bằng phiên bản đầy đủ của từ hoặc cụm từ đó. Ví dụ:
#
# "I'm" sẽ được mở rộng thành "I am".
# "can't" sẽ được mở rộng thành "cannot".
# "you'll" sẽ được mở rộng thành "you will".
# Mục tiêu của hàm này là giúp dễ dàng đọc và hiểu nội dung văn bản bằng việc loại bỏ các từ viết tắt và chuyển chúng thành phiên bản đầy đủ của các từ và cụm từ tương ứng.

# %%
import csv
import contractions

# Đọc dữ liệu từ tệp CSV
with open('dataset3.csv', 'r', newline='') as input_file:
    csv_reader = csv.DictReader(input_file)
    data = []

    # Định nghĩa hàm để mở rộng từ viết tắt
    def mo_rong_tu_viet_tat(text):
        return contractions.fix(text)

    # Duyệt qua từng dòng dữ liệu trong tệp nguồn và mở rộng từ viết tắt
    for row in csv_reader:
        row['Title'] = mo_rong_tu_viet_tat(row['Title'])
        row['Excerpt'] = mo_rong_tu_viet_tat(row['Excerpt'])
        row['Pub_Date'] = mo_rong_tu_viet_tat(row['Pub_Date'])
        data.append(row)

# Lưu dữ liệu đã mở rộng ra một tệp CSV mới
with open('dataset4.csv', 'w', newline='') as output_file:
    fieldnames = ['Title', 'Excerpt', 'Pub_Date']
    csv_writer = csv.DictWriter(output_file, fieldnames=fieldnames)

    csv_writer.writeheader()
    csv_writer.writerows(data)

# %% [markdown]
# # 5)  Remove special characters (bỏ kí tự đặc biệt)

# %% [markdown]
# ####
# Hàm loai_bo_ky_tu_dac_biet được sử dụng để loại bỏ các ký tự đặc biệt (ký tự không phải là chữ cái hoặc số) từ một chuỗi văn bản. Hàm này sử dụng biểu thức chính quy (regular expression) để thực hiện việc này. Dưới đây là cách nó hoạt động:
#
# Đầu vào của hàm loai_bo_ky_tu_dac_biet là một chuỗi văn bản mà bạn muốn loại bỏ các ký tự đặc biệt khỏi.
#
# Trong hàm này, biểu thức chính quy r'[^a-zA-Z0-9\s]' được sử dụng để xác định các ký tự đặc biệt. Đây là cách giải thích từng phần:
#
# ^ ở đầu biểu thức chính quy biểu thị "không phải" hoặc "loại trừ". Vì vậy, [^a-zA-Z0-9\s] nghĩa là "không phải là chữ cái hoặc số hoặc khoảng trắng".
# a-zA-Z đại diện cho tất cả các ký tự chữ cái tiếng Anh (kể cả chữ hoa và chữ thường).
# 0-9 đại diện cho tất cả các chữ số.
# \s đại diện cho khoảng trắng (space).
# Sử dụng re.sub, tất cả các ký tự khớp với biểu thức chính quy sẽ được thay thế bằng chuỗi rỗng '', có nghĩa là nó sẽ bị loại bỏ khỏi chuỗi văn bản.
#
# Kết quả của hàm loai_bo_ky_tu_dac_biet là chuỗi văn bản không chứa các ký tự đặc biệt.
#
# Hàm này có thể được sử dụng để làm sạch hoặc chuẩn hóa dữ liệu văn bản, để dễ dàng xử lý hoặc phân tích nó mà không cần quan tâm đến các ký tự đặc biệt

# %%
import csv
import re

# Đọc dữ liệu từ tệp CSV
with open('dataset4.csv', 'r', newline='') as input_file:
    csv_reader = csv.DictReader(input_file)
    data = []

    # Định nghĩa hàm để loại bỏ ký tự đặc biệt
    def loai_bo_ky_tu_dac_biet(text):
        # Sử dụng biểu thức chính quy để chỉ giữ lại các ký tự chữ và số
        return re.sub(r'[^a-zA-Z0-9\s]', '', text)

    # Duyệt qua từng dòng dữ liệu trong tệp nguồn và loại bỏ ký tự đặc biệt
    for row in csv_reader:
        row['Title'] = loai_bo_ky_tu_dac_biet(row['Title'])
        row['Excerpt'] = loai_bo_ky_tu_dac_biet(row['Excerpt'])
        row['Pub_Date'] = loai_bo_ky_tu_dac_biet(row['Pub_Date'])
        data.append(row)

# Lưu dữ liệu đã được xử lý ra một tệp CSV mới
with open('dataset5.csv', 'w', newline='') as output_file:
    fieldnames = ['Title', 'Excerpt', 'Pub_Date']
    csv_writer = csv.DictWriter(output_file, fieldnames=fieldnames)

    csv_writer.writeheader()
    csv_writer.writerows(data)

# %% [markdown]
# # 6) Text lemmatization

# %% [markdown]
# #
# Lemmatization là quá trình chuyển đổi các từ trong văn bản thành các từ gốc của chúng (gọi là lemma) để dễ dàng so sánh và phân tích. Trong tiếng Anh, lemmatization thường dựa trên từ điển để tìm các từ gốc. Dưới đây là cách bạn có thể áp dụng lemmatization cho dữ liệu trong cột "Title" của tệp CSV của bạn bằng sử dụng thư viện NLTK (Natural Language Toolkit):
#
# Đoạn mã lemmatize_text thực hiện các bước sau:
#
# tokens = word_tokenize(text): Hàm word_tokenize từ thư viện Natural Language Toolkit (NLTK) được sử dụng để tách chuỗi text thành danh sách các từ. Ví dụ, chuỗi "Create a series of posts" sẽ được chuyển thành danh sách ["Create", "a", "series", "of", "posts"].
#
# lemmatized_tokens = [lemmatizer.lemmatize(word) for word in tokens]: Duyệt qua từng từ trong danh sách tokens và áp dụng phương thức lemmatize từ đối tượng lemmatizer lên từng từ. Phương thức lemmatize sẽ lemmatize từng từ, nghĩa là chuyển từ về dạng gốc của nó. Ví dụ, "posts" có thể trở thành "post" sau khi lemmatize.
#
# return ' '.join(lemmatized_tokens): Sau khi lemmatize từng từ, chúng ta kết hợp lại các từ thành một chuỗi bằng cách sử dụng khoảng trắng ' ' như dấu phân cách. Điều này tạo ra chuỗi đã lemmatize.
#
# Ví dụ: Nếu bạn gọi lemmatize_text("Create a series of posts"), nó sẽ trả về chuỗi "Create a series of post" sau khi lemmatize.
#
#
#
# Trong quá trình lemmatization, các từ trong tiêu đề và phần tóm tắt đã được đưa về dạng nguyên mẫu (lemma), tức là dạng cơ bản của từ đó, chẳng hạn "Consuming" đã được chuyển thành "Consume", "responsibly" thành "responsibly", "Etiquette" thành "Etiquette", và cứ như vậy.
#
# Lưu ý rằng việc lemmatization sẽ tùy thuộc vào loại ngôn ngữ mà bạn sử dụng. Trong ví dụ trên, ngôn ngữ của văn bản là tiếng Anh. Đối với tiếng Việt, quá trình này có thể sử dụng một thư viện tiếng Việt như pyvi để thực hiện tương tự.

# %%
#import nltk
#nltk.download('wordnet')
#nltk.download('punkt')
import nltk
nltk.download('omw-1.4')

"""WordNetLemmatizer là một công cụ trong thư viện Natural Language Toolkit (NLTK) dùng để thực hiện lemmatization, tức là chuyển đổi từ vựng về dạng gốc của chúng.

word_tokenize là một hàm trong nltk được sử dụng để tách một đoạn văn bản thành danh sách các từ riêng lẻ. Thường được sử dụng để chuẩn hóa và xử lý dữ liệu văn bản, đặc biệt là khi thực hiện xử lý ngôn ngữ tự nhiên (NLP)."""
import csv
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize

# Đường dẫn đến tệp CSV đầu vào và đầu ra
input_csv_file = 'dataset5.csv'
output_csv_file = 'dataset6.csv'

# Tạo một đối tượng lemmatizer
lemmatizer = WordNetLemmatizer()

# Hàm lemmatization cho một chuỗi
def lemmatize_text(text):
    tokens = word_tokenize(text)  # Tách chuỗi thành danh sách các từ
    lemmatized_tokens = [lemmatizer.lemmatize(word) for word in tokens]  # Lemmatize từng từ
    return ' '.join(lemmatized_tokens)  # Kết hợp các từ thành chuỗi

# Mở tệp nguồn để đọc
with open(input_csv_file, mode='r', newline='') as input_file:
    reader = csv.reader(input_file)

    # Đọc dòng tiêu đề
    header = next(reader)

    # Mở tệp đích để ghi
    with open(output_csv_file, mode='w', newline='') as output_file:
        writer = csv.writer(output_file)

        # Ghi dòng tiêu đề
        writer.writerow(header)

        # Duyệt qua từng dòng dữ liệu trong tệp nguồn
        for row in reader:
            # Lemmatize nội dung cột "Title"
            lemmatized_title = lemmatize_text(row[0])
            row[0] = lemmatized_title  # Cập nhật lại cột "Title"

            # Lemmatize nội dung cột "Excerpt"
            lemmatized_excerpt = lemmatize_text(row[1])
            row[1] = lemmatized_excerpt  # Cập nhật lại cột "Excerpt"

            # Lemmatize nội dung cột "Pub_Date"
            lemmatized_excerpt = lemmatize_text(row[2])
            row[2] = lemmatized_excerpt  # Cập nhật lại cột "Pub_Date"

            # Ghi dữ liệu đã xử lý vào tệp đích
            writer.writerow(row)

print("Dữ liệu đã được lemmatized và lưu vào tệp lemmatized_dataset.csv.")
# Out:
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# Dữ liệu đã được lemmatized và lưu vào tệp lemmatized_dataset.csv.

# %%
df = pd.read_csv('dataset6.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Title     120 non-null    object
#  1   Excerpt   120 non-null    object
#  2   Pub_Date  120 non-null    object
# dtypes: object(3)
# memory usage: 2.9+ KB

# %% [markdown]
# # 7) Text stemming

# %% [markdown]
# ####
# Mã trên là ví dụ về cách sử dụng stemming trong xử lý văn bản. Stemming là một quá trình cắt bớt các hậu tố của các từ để giữ lại từ gốc hoặc stem của từ đó. Stemming giúp chuẩn hóa văn bản bằng cách loại bỏ các biến thể từ của một từ gốc, giúp các từ có nghĩa tương tự như "run", "running", "ran" trở thành cùng một từ "run".
#
# Trong ví dụ này:
#
# PorterStemmer() là một đối tượng stemmer được sử dụng, trong trường hợp này, đó là Porter Stemmer, một trong những thuật toán stemming phổ biến.
#
# Hàm stem_text(text) nhận một câu hoặc một đoạn văn bản (biểu đạng dưới dạng chuỗi) và thực hiện stemming trên nó.
#
# Hàm này sẽ tách câu thành các từ (sử dụng word_tokenize từ thư viện NLTK), sau đó thực hiện stemming cho mỗi từ trong câu và kết hợp chúng lại để tạo một câu mới chỉ chứa các từ gốc sau khi stemming.
#
# Ví dụ này chỉ áp dụng stemming cho mỗi từ trong văn bản, nhưng thường thì nó sẽ được áp dụng cho tất cả các từ trong một tài liệu hoặc bộ dữ liệu để chuẩn hóa văn bản trước khi sử dụng trong các tác vụ xử lý ngôn ngữ tự nhiên.

# %%
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
import pandas as pd

# Đọc dữ liệu từ tệp CSV
data = pd.read_csv('dataset6.csv')  # Thay 'data.csv' bằng tên tệp CSV chứa dữ liệu của bạn

# Khởi tạo Stemmer
stemmer = PorterStemmer()

# Tạo một hàm để thực hiện stemming cho một câu
def stem_text(text):
    words = word_tokenize(text)#Đây là một hàm từ thư viện NLTK (Natural Language Toolkit) được sử dụng để tách chuỗi văn bản thành danh sách các từ (list of words). Kết quả là một danh sách, trong đó mỗi phần tử là một từ riêng lẻ trong chuỗi văn bản.
    #stemmed_words có tác dụng áp dụng quá trình stemming lên từng từ trong danh sách các từ đã được tách từ văn bản.
    stemmed_words = [stemmer.stem(word) for word in words]#stemmer.stem(word): Đây là một phần của quá trình stemming. Đối tượng stemmer (có thể là một stemmer cụ thể như PorterStemmer trong trường hợp này) là một phần mềm được sử dụng để chuyển đổi các từ về dạng cơ bản hoặc gốc của chúng. Stemming loại bỏ các hậu tố (suffix) của từ để giúp đồng nhất hóa các từ có cùng nguồn gốc. Ví dụ: từ "programming" có thể được đưa về dạng "program."      word trong vòng lặp: Đây là từng từ trong danh sách words (danh sách các từ đã được tách từ văn bản).
    #Dòng mã return ' '.join(stemmed_words) có nhiệm vụ gom các từ trong danh sách stemmed_words thành một chuỗi duy nhất, cách nhau bởi khoảng trắng.
    return ' '.join(stemmed_words)

# Áp dụng hàm stemming cho tất cả 3 cột
data['Stemmed_Title'] = data['Title'].apply(stem_text)
data['Stemmed_Excerpt'] = data['Excerpt'].apply(stem_text)
data['Stemmed_Pub_Date'] = data['Pub_Date'].apply(stem_text)

last_three_columns = data.iloc[:, -3:]  # Sử dụng chỉ số cột
# Lưu dữ liệu đã được stemming vào một tệp CSV mới
data.to_csv('dataset7.csv', index=False)

# %%
import pandas as pd

# Đọc tệp CSV
data = pd.read_csv('dataset7.csv')

# Chọn 3 cột cuối cùng (ví dụ: Stemmed_Title,Stemmed_Excerpt,Stemmed_Pub_Date)
selected_columns = data.iloc[:, -3:]

# Lưu kết quả vào một tệp CSV mới
selected_columns.to_csv('dataset7New.csv', index=False)

# %% [markdown]
# # 8)  Remove stopwords

# %% [markdown]
# ####
# Stopwords là những từ phổ biến trong ngôn ngữ mà trong nhiều trường hợp không mang nhiều ý nghĩa hoặc thông tin quan trọng khi xử lý ngôn ngữ tự nhiên. Các từ này thường được loại bỏ khỏi văn bản để làm cho dữ liệu gọn hơn và giảm nhiễu trong quá trình xử lý ngôn ngữ.
#
# Ví dụ về stopwords trong tiếng Anh bao gồm "the," "and," "of," "in," "to," và nhiều từ khác. Tuy nhiên, danh sách stopwords có thể thay đổi tùy theo ngữ cảnh và nhiệm vụ cụ thể. Khi thực hiện xử lý ngôn ngữ tự nhiên, loại bỏ stopwords giúp tập trung vào những từ quan trọng hơn và cải thiện hiệu suất của các mô hình hoặc tác vụ xử lý ngôn ngữ.

# %%
#Tải bộ dữ liệu stopwords và các tài liệu khác bằng cách chạy mã sau trong Python:
#import nltk
#nltk.download('stopwords')


import pandas as pd
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# Đọc tệp CSV
data = pd.read_csv('dataset7New.csv')

# Tải danh sách stopwords tiếng Anh từ NLTK
stop_words = set(stopwords.words('english'))

# Hàm loại bỏ stopwords từ một văn bản
def remove_stopwords(text):
    words = word_tokenize(text)
    filtered_words = [word for word in words if word.lower() not in stop_words]
    return ' '.join(filtered_words)

# Áp dụng hàm loại bỏ stopwords cho từng cột
data['Stemmed_Title'] = data['Stemmed_Title'].apply(remove_stopwords)
data['Stemmed_Excerpt'] = data['Stemmed_Excerpt'].apply(remove_stopwords)
data['Stemmed_Pub_Date'] = data['Stemmed_Pub_Date'].apply(remove_stopwords)

# Chọn 3 cột cuối cùng 
selected_columns = data.iloc[:, -3:]

# Lưu kết quả vào một tệp CSV mới
selected_columns.to_csv('dataset8.csv', index=False)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.

# %% [markdown]
# # 9)  Building a text normalizer
# ######
# Building a text normalizer" không phải là một thuật ngữ kỹ thuật cụ thể trong lĩnh vực xử lý ngôn ngữ tự nhiên (NLP) hoặc khoa học máy tính. Tuy nhiên, nó có thể ám chỉ đến việc tạo ra một ứng dụng hoặc hệ thống để chuẩn hóa văn bản hoặc văn bản trong quá trình xử lý ngôn ngữ tự nhiên.
#
# Text normalization là quá trình biến đổi văn bản để đưa về dạng chuẩn hóa, giúp giảm thiểu sự đa dạng trong ngôn ngữ và làm cho dữ liệu dễ dàng xử lý hơn. Text normalization bao gồm nhiều tác vụ như:
#
# **Chuyển chữ hoa thành chữ thường:** Đảm bảo rằng tất cả các ký tự đều ở dạng chữ thường để tránh sự đa dạng do việc sử dụng ký tự hoa.
#
# **Loại bỏ ký tự đặc biệt:** Loại bỏ các ký tự đặc biệt như dấu câu, ký tự đặc biệt khỏi văn bản.
#
# **Loại bỏ stopwords:** Loại bỏ các từ phổ biến như "và," "hoặc," "một số," v.v. để tập trung vào các từ quan trọng hơn.
#
# **Lemmatisation và stemming:** Chuyển từ về dạng cơ bản hoặc giảm từ về dạng gốc của nó.
#
# **Xử lý số liệu:** Chuẩn hóa và xử lý số liệu trong văn bản.
#
# Vì vậy, "building a text normalizer" có thể đề cập đến việc phát triển hoặc xây dựng một hệ thống hoặc mã nguồn để thực hiện các tác vụ chuẩn hóa văn bản như những điều đã nêu trên. Các ứng dụng NLP thường sử dụng các bước chuẩn hóa văn bản như vậy để chuẩn hóa dữ liệu đầu vào và làm cho nó dễ dàng xử lý hơn.
