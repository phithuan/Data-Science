# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://finance.yahoo.com/quote/F/financials/'
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}

response = requests.get(url, headers=headers)

if response.status_code == 404:
    print("Page not found (404).")
else:
    print("Success:", response.status_code)
# Out:
# Success: 200

# %%
response.content
# Out:
# b'<!doctype html>\n<html lang="en-US" theme="light"  data-color-scheme="light" class="desktop neo-green dock-upscale">\n    <head>\n        <meta charset="utf-8" />\n        <meta name="viewport" content="width=device-width, initial-scale=1" />\n        <meta name="oath:guce:consent-host" content="guce.yahoo.com" />\n        <link rel="preconnect" href="//s.yimg.com" crossorigin="anonymous"><link rel="preconnect" href="//geo.yahoo.com"/><link rel="preconnect" href="//query1.finance.yahoo.com"/><link rel="preconnect" href="//query2.finance.yahoo.com"/><link rel="preconnect" href="//consent.cmp.oath.com"/><link rel="preload" href="/__rapidworker-1.2.js" as="worker"/><link rel="preconnect" href="https://s.yimg.com/uc/finance/webcore/js/_staticFinProtobuf.4b1559b8e4645fd93a12.js"/><link rel="preconnect" href="https://cdn.jsdelivr.net/npm/protobufjs@7.1.2/dist/minimal/protobuf.min.js"/><script>window.finNeoPageStart = Date.now();</script><script>(function(){if(!window.YAHOO){window.YAHOO=
# ...

# %%
# Giả sử 'html_content' chứa mã HTML đầy đủ
soup = BeautifulSoup(response.content, 'html.parser')
table_body = soup.find('div', class_='row yf-1ezv2n5')

if table_body:
    print(table_body.prettify())  # In ra mã HTML đẹp hơn
else:
    print("Không tìm thấy phần tử có lớp 'tableBody yf-1pgoo1f'")
# Out:
# <div class="row yf-1ezv2n5">
#  <div class="sticky column yf-1ezv2n5">
#   Breakdown
#  </div>
#  <div class="column yf-1ezv2n5 alt">
#   TTM
#  </div>
#  <div class="column yf-1ezv2n5">
#   12/31/2023
#  </div>
#  <div class="column yf-1ezv2n5 alt">
#   12/31/2022
#  </div>
#  <div class="column yf-1ezv2n5">
#   12/31/2021
#  </div>
#  <div class="column yf-1ezv2n5 alt">
#   12/31/2020
#  </div>
#  <div class="column yf-1ezv2n5">
#   12/31/2019
#  </div>
# </div>

# %%
import pandas as pd
from bs4 import BeautifulSoup

# Mã HTML bạn đã cung cấp
html_content = '''
<div class="row yf-1ezv2n5">
 <div class="sticky column yf-1ezv2n5">
  Breakdown
 </div>
 <div class="column yf-1ezv2n5 alt">
  TTM
 </div>
 <div class="column yf-1ezv2n5">
  12/31/2023
 </div>
 <div class="column yf-1ezv2n5 alt">
  12/31/2022
 </div>
 <div class="column yf-1ezv2n5">
  12/31/2021
 </div>
 <div class="column yf-1ezv2n5 alt">
  12/31/2020
 </div>
 <div class="column yf-1ezv2n5">
  12/31/2019
 </div>
</div>
'''

# Phân tích HTML
soup = BeautifulSoup(html_content, 'html.parser')

# Trích xuất các tiêu đề cột
columns = ['Breakdown'] + ['TTM'] +[col.get_text(strip=True) for col in soup.find_all('div', class_='column yf-1ezv2n5')]

# Tạo bảng dữ liệu với các cột
df = pd.DataFrame(columns=columns)

# Hiển thị bảng dữ liệu
print(df)
# Out:
# Empty DataFrame
# Columns: [Breakdown, TTM]
# Index: []

# %%
# Giả sử 'html_content' chứa mã HTML đầy đủ
soup = BeautifulSoup(response.content, 'html.parser')
table_body = soup.find('div', class_='tableBody yf-1pgoo1f')

if table_body:
    print(table_body.prettify())  # In ra mã HTML đẹp hơn
else:
    print("Không tìm thấy phần tử có lớp 'tableBody yf-1pgoo1f'")
# Out:
# <div class="tableBody yf-1pgoo1f">
#  <div class="row lv-0 yf-1xjz32c">
#   <div class="column sticky yf-1xjz32c">
#    <button aria-label="Total Revenue" class="icon-btn fin-size-small tw-p-0 rounded yf-1al6vaf" data-ylk="elm:expand;elmt:btn;itc:1;sec:qsp-financials;slk:TotalRevenue">
#     <div class="icon fin-icon primary-icn sz-medium yf-7v4gbg">
#      <!-- HTML_TAG_START -->
#      <svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg">
#       <path d="M16.59 8.59 12 13.17 7.41 8.59 6 10l6 6 6-6z">
#       </path>
#      </svg>
#      <!-- HTML_TAG_END -->
#     </div>
#    </button>
#    <div class="rowTitle yf-1xjz32c" title="Total Revenue">
#     Total Revenue
#    </div>
#   </div>
#   <div class="column yf-1xjz32c alt">
#    180,348,000.00
#   </div>
#   <div class="column yf-1xjz32c">
#    176,191,000.00
#   </div>
#   <div class="column yf-1xjz32c alt">
#    158,057,000.00
#   </div>
#   <div class="column yf-1xjz32c">
#    136,341,000.00
#   </div>
# ...

# %%
print(table_body)
# Out:
# <div class="tableBody yf-1pgoo1f"> <div class="row lv-0 yf-1xjz32c"><div class="column sticky yf-1xjz32c"><button aria-label="Total Revenue" class="icon-btn fin-size-small tw-p-0 rounded yf-1al6vaf" data-ylk="elm:expand;elmt:btn;itc:1;sec:qsp-financials;slk:TotalRevenue"> <div class="icon fin-icon primary-icn sz-medium yf-7v4gbg"><!-- HTML_TAG_START --><svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M16.59 8.59 12 13.17 7.41 8.59 6 10l6 6 6-6z"></path></svg><!-- HTML_TAG_END --></div> </button> <div class="rowTitle yf-1xjz32c" title="Total Revenue">Total Revenue</div></div> <div class="column yf-1xjz32c alt">180,348,000.00 </div><div class="column yf-1xjz32c">176,191,000.00 </div><div class="column yf-1xjz32c alt">158,057,000.00 </div><div class="column yf-1xjz32c">136,341,000.00 </div><div class="column yf-1xjz32c alt">127,144,000.00 </div><div class="column yf-1xjz32c">-- </div></div> <div class="row lv-0 yf-1xjz32c"><div class="column sticky yf-1xjz32c"> <div 
# ...

# %%
from bs4 import BeautifulSoup

# HTML content chứa dữ liệu bạn muốn xử lý
html_content = '''
<div class="tableBody yf-1pgoo1f">
 <div class="row lv-0 yf-1xjz32c">
  <div class="column sticky yf-1xjz32c">
   <button aria-label="Total Revenue" class="icon-btn fin-size-small tw-p-0 rounded yf-1al6vaf" data-ylk="elm:expand;elmt:btn;itc:1;sec:qsp-financials;slk:TotalRevenue">
    <div class="icon fin-icon primary-icn sz-medium yf-7v4gbg">
     <!-- HTML_TAG_START -->
     <svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg">
      <path d="M16.59 8.59 12 13.17 7.41 8.59 6 10l6 6 6-6z">
      </path>
     </svg>
     <!-- HTML_TAG_END -->
    </div>
   </button>
   <div class="rowTitle yf-1xjz32c" title="Total Revenue">
    Total Revenue
   </div>
  </div>
  <div class="column yf-1xjz32c alt">
   180,348,000.00
  </div>
  <div class="column yf-1xjz32c">
   176,191,000.00
  </div>
  <div class="column yf-1xjz32c alt">
   158,057,000.00
  </div>
  <div class="column yf-1xjz32c">
   136,341,000.00
  </div>
  <div class="column yf-1xjz32c alt">
   127,144,000.00
  </div>
  <div class="column yf-1xjz32c">
   --
  </div>
 </div>
 <div class="row lv-0 yf-1xjz32c">
  <div class="column sticky yf-1xjz32c">
   <div class="rowTitle yf-1xjz32c" title="Cost of Revenue">
    Cost of Revenue
   </div>
  </div>
  <div class="column yf-1xjz32c alt">
   165,856,000.00
  </div>
  <div class="column yf-1xjz32c">
   160,031,000.00
  </div>
  <div class="column yf-1xjz32c alt">
   140,893,000.00
  </div>
  <div class="column yf-1xjz32c">
   119,903,000.00
  </div>
  <div class="column yf-1xjz32c alt">
   121,359,000.00
  </div>
  <div class="column yf-1xjz32c">
   --
  </div>
 </div>
 <div class="row lv-0 yf-1xjz32c">
  <div class="column sticky yf-1xjz32c">
   <div class="rowTitle yf-1xjz32c" title="Gross Profit">
    Gross Profit
   </div>
  </div>
  <div class="column yf-1xjz32c alt">
   14,492,000.00
  </div>
  <div class="column yf-1xjz32c">
   16,160,000.00
  </div>
  <div class="column yf-1xjz32c alt">
   17,164,000.00
  </div>
  <div class="column yf-1xjz32c">
   16,438,000.00
  </div>
  <div class="column yf-1xjz32c alt">
   5,785,000.00
  </div>
  <div class="column yf-1xjz32c">
   --
  </div>
 </div>
 <div class="row lv-0 yf-1xjz32c">
  <div class="column sticky yf-1xjz32c">
   <button aria-label="Operating Expense" class="icon-btn fin-size-small tw-p-0 rounded yf-1al6vaf" data-ylk="elm:expand;elmt:btn;itc:1;sec:qsp-financials;slk:OperatingExpense">
    <div class="icon fin-icon primary-icn sz-medium yf-7v4gbg">
     <!-- HTML_TAG_START -->
     <svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg">
      <path d="M16.59 8.59 12 13.17 7.41 8.59 6 10l6 6 6-6z">
      </path>
     </svg>
     <!-- HTML_TAG_END -->
    </div>
   </button>
   <div class="rowTitle yf-1xjz32c" title="Operating Expense">
    Operating Expense
   </div>
  </div>
  <div class="column yf-1xjz32c alt">
   10,500,000.00
  </div>
  <div class="column yf-1xjz32c">
   10,702,000.00
  </div>
  <div class="column yf-1xjz32c alt">
   10,888,000.00
  </div>
  <div class="column yf-1xjz32c">
   11,915,000.00
  </div>
  <div class="column yf-1xjz32c alt">
   10,193,000.00
  </div>
  <div class="column yf-1xjz32c">
   --
  </div>
 </div>
 <div class="row lv-0 yf-1xjz32c">
  <div class="column sticky yf-1xjz32c">
   <div class="rowTitle yf-1xjz32c" title="Operating Income">
    Operating Income
   </div>
  </div>
  <div class="column yf-1xjz32c alt">
   3,992,000.00
  </div>
  <div class="column yf-1xjz32c">
   5,458,000.00
  </div>
  <div class="column yf-1xjz32c alt">
   6,276,000.00
  </div>
  <div class="column yf-1xjz32c">
   4,523,000.00
  </div>
  <div class="column yf-1xjz32c alt">
   -4,408,000.00
  </div>
  <div class="column yf-1xjz32c">
   --
  </div>
 </div>
 <div class="row lv-0 yf-1xjz32c">
  <div class="column sticky yf-1xjz32c">
   <button aria-label="Net Non Operating Interest Income Expense" class="icon-btn fin-size-small tw-p-0 rounded yf-1al6vaf" data-ylk="elm:expand;elmt:btn;itc:1;sec:qsp-financials;slk:NetNonOperatingInterestIncomeExpense">
    <div class="icon fin-icon primary-icn sz-medium yf-7v4gbg">
     <!-- HTML_TAG_START -->
     <svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg">
      <path d="M16.59 8.59 12 13.17 7.41 8.59 6 10l6 6 6-6z">
      </path>
     </svg>
     <!-- HTML_TAG_END -->
    </div>
   </button>
   <div class="rowTitle yf-1xjz32c" title="Net Non Operating Interest Income Expense">
    Net Non Operating Interest Income Expense
   </div>
  </div>
  <div class="column yf-1xjz32c alt">
   353,000.00
  </div>
  <div class="column yf-1xjz32c">
   249,000.00
  </div>
  <div class="column yf-1xjz32c alt">
   -643,000.00
  </div>
  <div class="column yf-1xjz32c">
   -1,542,000.00
  </div>
  <div class="column yf-1xjz32c alt">
   -1,199,000.00
  </div>
  <div class="column yf-1xjz32c">
   --
  </div>
 </div>
 <div class="row lv-0 yf-1xjz32c">
  <div class="column sticky yf-1xjz32c">
   <button aria-label="Other Income Expense" class="icon-btn fin-size-small tw-p-0 rounded yf-1al6vaf" data-ylk="elm:expand;elmt:btn;itc:1;sec:qsp-financials;slk:OtherIncomeExpense">
    <div class="icon fin-icon primary-icn sz-medium yf-7v4gbg">
     <!-- HTML_TAG_START -->
     <svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg">
      <path d="M16.59 8.59 12 13.17 7.41 8.59 6 10l6 6 6-6z">
      </path>
     </svg>
     <!-- HTML_TAG_END -->
    </div>
   </button>
   <div class="rowTitle yf-1xjz32c" title="Other Income Expense">
    Other Income Expense
   </div>
  </div>
  <div class="column yf-1xjz32c alt">
   -775,000.00
  </div>
  <div class="column yf-1xjz32c">
   -1,740,000.00
  </div>
  <div class="column yf-1xjz32c alt">
   -8,649,000.00
  </div>
  <div class="column yf-1xjz32c">
   14,799,000.00
  </div>
  <div class="column yf-1xjz32c alt">
   4,491,000.00
  </div>
  <div class="column yf-1xjz32c">
   --
  </div>
 </div>
 <div class="row lv-0 yf-1xjz32c">
  <div class="column sticky yf-1xjz32c">
   <div class="rowTitle yf-1xjz32c" title="Pretax Income">
    Pretax Income
   </div>
  </div>
  <div class="column yf-1xjz32c alt">
   3,570,000.00
  </div>
  <div class="column yf-1xjz32c">
   3,967,000.00
  </div>
  <div class="column yf-1xjz32c alt">
   -3,016,000.00
  </div>
  <div class="column yf-1xjz32c">
   17,780,000.00
  </div>
  <div class="column yf-1xjz32c alt">
   -1,116,000.00
  </div>
  <div class="column yf-1xjz32c">
   --
  </div>
 </div>
 <div class="row lv-0 yf-1xjz32c">
  <div class="column sticky yf-1xjz32c">
   <div class="rowTitle yf-1xjz32c" title="Tax Provision">
    Tax Provision
   </div>
  </div>
  <div class="column yf-1xjz32c alt">
   -247,000.00
  </div>
  <div class="column yf-1xjz32c">
   -362,000.00
  </div>
  <div class="column yf-1xjz32c alt">
   -864,000.00
  </div>
  <div class="column yf-1xjz32c">
   -130,000.00
  </div>
  <div class="column yf-1xjz32c alt">
   160,000.00
  </div>
  <div class="column yf-1xjz32c">
   --
  </div>
 </div>
 <div class="row lv-0 yf-1xjz32c">
  <div class="column sticky yf-1xjz32c">
   <button aria-label="Net Income Common Stockholders" class="icon-btn fin-size-small tw-p-0 rounded yf-1al6vaf" data-ylk="elm:expand;elmt:btn;itc:1;sec:qsp-financials;slk:NetIncomeCommonStockholders">
    <div class="icon fin-icon primary-icn sz-medium yf-7v4gbg">
     <!-- HTML_TAG_START -->
     <svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg">
      <path d="M16.59 8.59 12 13.17 7.41 8.59 6 10l6 6 6-6z">
      </path>
     </svg>
     <!-- HTML_TAG_END -->
    </div>
   </button>
   <div class="rowTitle yf-1xjz32c" title="Net Income Common Stockholders">
    Net Income Common Stockholders
   </div>
  </div>
  <div class="column yf-1xjz32c alt">
   3,836,000.00
  </div>
  <div class="column yf-1xjz32c">
   4,347,000.00
  </div>
  <div class="column yf-1xjz32c alt">
   -1,981,000.00
  </div>
  <div class="column yf-1xjz32c">
   17,937,000.00
  </div>
  <div class="column yf-1xjz32c alt">
   -1,279,000.00
  </div>
  <div class="column yf-1xjz32c">
   --
  </div>
 </div>
 <div class="row lv-0 yf-1xjz32c">
  <div class="column sticky yf-1xjz32c">
   <div class="rowTitle yf-1xjz32c" title="Diluted NI Available to Com Stockholders">
    Diluted NI Available to Com Stockholders
   </div>
  </div>
  <div class="column yf-1xjz32c alt">
   3,836,000.00
  </div>
  <div class="column yf-1xjz32c">
   4,347,000.00
  </div>
  <div class="column yf-1xjz32c alt">
   -1,981,000.00
  </div>
  <div class="column yf-1xjz32c">
   17,937,000.00
  </div>
  <div class="column yf-1xjz32c alt">
   -1,279,000.00
  </div>
  <div class="column yf-1xjz32c">
   --
  </div>
 </div>
 <div class="row lv-0 yf-1xjz32c">
  <div class="column sticky yf-1xjz32c">
   <div class="rowTitle yf-1xjz32c" title="Basic EPS">
    Basic EPS
   </div>
  </div>
  <div class="column yf-1xjz32c alt">
   0.96
  </div>
  <div class="column yf-1xjz32c">
   1.09
  </div>
  <div class="column yf-1xjz32c alt">
   -0.49
  </div>
  <div class="column yf-1xjz32c">
   4.49
  </div>
  <div class="column yf-1xjz32c alt">
   -0.32
  </div>
  <div class="column yf-1xjz32c">
   --
  </div>
 </div>
 <div class="row lv-0 yf-1xjz32c">
  <div class="column sticky yf-1xjz32c">
   <div class="rowTitle yf-1xjz32c" title="Diluted EPS">
    Diluted EPS
   </div>
  </div>
  <div class="column yf-1xjz32c alt">
   0.96
  </div>
  <div class="column yf-1xjz32c">
   1.08
  </div>
  <div class="column yf-1xjz32c alt">
   -0.49
  </div>
  <div class="column yf-1xjz32c">
   4.45
  </div>
  <div class="column yf-1xjz32c alt">
   -0.32
  </div>
  <div class="column yf-1xjz32c">
   --
  </div>
 </div>
 <div class="row lv-0 yf-1xjz32c">
  <div class="column sticky yf-1xjz32c">
   <div class="rowTitle yf-1xjz32c" title="Basic Average Shares">
    Basic Average Shares
   </div>
  </div>
  <div class="column yf-1xjz32c alt">
   3,991,000.00
  </div>
  <div class="column yf-1xjz32c">
   3,998,000.00
  </div>
  <div class="column yf-1xjz32c alt">
   4,014,000.00
  </div>
  <div class="column yf-1xjz32c">
   3,991,000.00
  </div>
  <div class="column yf-1xjz32c alt">
   3,973,000.00
  </div>
  <div class="column yf-1xjz32c">
   --
  </div>
 </div>
 <div class="row lv-0 yf-1xjz32c">
  <div class="column sticky yf-1xjz32c">
   <div class="rowTitle yf-1xjz32c" title="Diluted Average Shares">
    Diluted Average Shares
   </div>
  </div>
  <div class="column yf-1xjz32c alt">
   4,034,500.00
  </div>
  <div class="column yf-1xjz32c">
   4,041,000.00
  </div>
  <div class="column yf-1xjz32c alt">
   4,056,000.00
  </div>
  <div class="column yf-1xjz32c">
   4,034,000.00
  </div>
  <div class="column yf-1xjz32c alt">
   3,973,000.00
  </div>
  <div class="column yf-1xjz32c">
   --
  </div>
 </div>
 <div class="row lv-0 yf-1xjz32c">
  <div class="column sticky yf-1xjz32c">
   <div class="rowTitle yf-1xjz32c" title="Total Operating Income as Reported">
    Total Operating Income as Reported
   </div>
  </div>
  <div class="column yf-1xjz32c alt">
   3,992,000.00
  </div>
  <div class="column yf-1xjz32c">
   5,458,000.00
  </div>
  <div class="column yf-1xjz32c alt">
   6,276,000.00
  </div>
  <div class="column yf-1xjz32c">
   4,523,000.00
  </div>
  <div class="column yf-1xjz32c alt">
   -4,408,000.00
  </div>
  <div class="column yf-1xjz32c">
   --
  </div>
 </div>
 <div class="row lv-0 yf-1xjz32c">
  <div class="column sticky yf-1xjz32c">
   <div class="rowTitle yf-1xjz32c" title="Total Expenses">
    Total Expenses
   </div>
  </div>
  <div class="column yf-1xjz32c alt">
   176,356,000.00
  </div>
  <div class="column yf-1xjz32c">
   170,733,000.00
  </div>
  <div class="column yf-1xjz32c alt">
   151,781,000.00
  </div>
  <div class="column yf-1xjz32c">
   131,818,000.00
  </div>
  <div class="column yf-1xjz32c alt">
   131,552,000.00
  </div>
  <div class="column yf-1xjz32c">
   --
  </div>
 </div>
 <div class="row lv-0 yf-1xjz32c">
  <div class="column sticky yf-1xjz32c">
   <div class="rowTitle yf-1xjz32c" title="Net Income from Continuing &amp; Discontinued Operation">
    Net Income from Continuing &amp; Discontinued Operation
   </div>
  </div>
  <div class="column yf-1xjz32c alt">
   3,836,000.00
  </div>
  <div class="column yf-1xjz32c">
   4,347,000.00
  </div>
  <div class="column yf-1xjz32c alt">
   -1,981,000.00
  </div>
  <div class="column yf-1xjz32c">
   17,937,000.00
  </div>
  <div class="column yf-1xjz32c alt">
   -1,279,000.00
  </div>
  <div class="column yf-1xjz32c">
   --
  </div>
 </div>
 <div class="row lv-0 yf-1xjz32c">
  <div class="column sticky yf-1xjz32c">
   <div class="rowTitle yf-1xjz32c" title="Normalized Income">
    Normalized Income
   </div>
  </div>
  <div class="column yf-1xjz32c alt">
   3,875,500.00
  </div>
  <div class="column yf-1xjz32c">
   4,508,950.00
  </div>
  <div class="column yf-1xjz32c alt">
   3,473,246.00
  </div>
  <div class="column yf-1xjz32c">
   12,493,390.00
  </div>
  <div class="column yf-1xjz32c alt">
   -1,515,520.00
  </div>
  <div class="column yf-1xjz32c">
   --
  </div>
 </div>
 <div class="row lv-0 yf-1xjz32c">
  <div class="column sticky yf-1xjz32c">
   <div class="rowTitle yf-1xjz32c" title="Interest Income">
    Interest Income
   </div>
  </div>
  <div class="column yf-1xjz32c alt">
   1,624,000.00
  </div>
  <div class="column yf-1xjz32c">
   1,567,000.00
  </div>
  <div class="column yf-1xjz32c alt">
   639,000.00
  </div>
  <div class="column yf-1xjz32c">
   261,000.00
  </div>
  <div class="column yf-1xjz32c alt">
   452,000.00
  </div>
  <div class="column yf-1xjz32c">
   --
  </div>
 </div>
 <div class="row lv-0 yf-1xjz32c">
  <div class="column sticky yf-1xjz32c">
   <div class="rowTitle yf-1xjz32c" title="Interest Expense">
    Interest Expense
   </div>
  </div>
  <div class="column yf-1xjz32c alt">
   1,271,000.00
  </div>
  <div class="column yf-1xjz32c">
   1,318,000.00
  </div>
  <div class="column yf-1xjz32c alt">
   1,282,000.00
  </div>
  <div class="column yf-1xjz32c">
   1,803,000.00
  </div>
  <div class="column yf-1xjz32c alt">
   1,651,000.00
  </div>
  <div class="column yf-1xjz32c">
   --
  </div>
 </div>
 <div class="row lv-0 yf-1xjz32c">
  <div class="column sticky yf-1xjz32c">
   <div class="rowTitle yf-1xjz32c" title="Net Interest Income">
    Net Interest Income
   </div>
  </div>
  <div class="column yf-1xjz32c alt">
   353,000.00
  </div>
  <div class="column yf-1xjz32c">
   249,000.00
  </div>
  <div class="column yf-1xjz32c alt">
   -643,000.00
  </div>
  <div class="column yf-1xjz32c">
   -1,542,000.00
  </div>
  <div class="column yf-1xjz32c alt">
   -1,199,000.00
  </div>
  <div class="column yf-1xjz32c">
   --
  </div>
 </div>
 <div class="row lv-0 yf-1xjz32c">
  <div class="column sticky yf-1xjz32c">
   <div class="rowTitle yf-1xjz32c" title="EBIT">
    EBIT
   </div>
  </div>
  <div class="column yf-1xjz32c alt">
   4,841,000.00
  </div>
  <div class="column yf-1xjz32c">
   5,285,000.00
  </div>
  <div class="column yf-1xjz32c alt">
   -1,734,000.00
  </div>
  <div class="column yf-1xjz32c">
   19,583,000.00
  </div>
  <div class="column yf-1xjz32c alt">
   535,000.00
  </div>
  <div class="column yf-1xjz32c">
   --
  </div>
 </div>
 <div class="row lv-0 yf-1xjz32c">
  <div class="column sticky yf-1xjz32c">
   <div class="rowTitle yf-1xjz32c" title="EBITDA">
    EBITDA
   </div>
  </div>
  <div class="column yf-1xjz32c alt">
   11,166,000.00
  </div>
  <div class="column yf-1xjz32c">
   11,808,000.00
  </div>
  <div class="column yf-1xjz32c alt">
   4,759,000.00
  </div>
  <div class="column yf-1xjz32c">
   25,543,000.00
  </div>
  <div class="column yf-1xjz32c alt">
   7,992,000.00
  </div>
  <div class="column yf-1xjz32c">
   --
  </div>
 </div>
 <div class="row lv-0 yf-1xjz32c">
  <div class="column sticky yf-1xjz32c">
   <div class="rowTitle yf-1xjz32c" title="Reconciled Cost of Revenue">
    Reconciled Cost of Revenue
   </div>
  </div>
  <div class="column yf-1xjz32c alt">
   165,856,000.00
  </div>
  <div class="column yf-1xjz32c">
   160,031,000.00
  </div>
  <div class="column yf-1xjz32c alt">
   140,893,000.00
  </div>
  <div class="column yf-1xjz32c">
   119,903,000.00
  </div>
  <div class="column yf-1xjz32c alt">
   121,359,000.00
  </div>
  <div class="column yf-1xjz32c">
   --
  </div>
 </div>
 <div class="row lv-0 yf-1xjz32c">
  <div class="column sticky yf-1xjz32c">
   <div class="rowTitle yf-1xjz32c" title="Reconciled Depreciation">
    Reconciled Depreciation
   </div>
  </div>
  <div class="column yf-1xjz32c alt">
   6,325,000.00
  </div>
  <div class="column yf-1xjz32c">
   6,523,000.00
  </div>
  <div class="column yf-1xjz32c alt">
   6,493,000.00
  </div>
  <div class="column yf-1xjz32c">
   5,960,000.00
  </div>
  <div class="column yf-1xjz32c alt">
   7,457,000.00
  </div>
  <div class="column yf-1xjz32c">
   --
  </div>
 </div>
 <div class="row lv-0 yf-1xjz32c">
  <div class="column sticky yf-1xjz32c">
   <div class="rowTitle yf-1xjz32c" title="Net Income from Continuing Operation Net Minority Interest">
    Net Income from Continuing Operation Net Minority Interest
   </div>
  </div>
  <div class="column yf-1xjz32c alt">
   3,836,000.00
  </div>
  <div class="column yf-1xjz32c">
   4,347,000.00
  </div>
  <div class="column yf-1xjz32c alt">
   -1,981,000.00
  </div>
  <div class="column yf-1xjz32c">
   17,937,000.00
  </div>
  <div class="column yf-1xjz32c alt">
   -1,279,000.00
  </div>
  <div class="column yf-1xjz32c">
   --
  </div>
 </div>
 <div class="row lv-0 yf-1xjz32c">
  <div class="column sticky yf-1xjz32c">
   <div class="rowTitle yf-1xjz32c" title="Total Unusual Items Excluding Goodwill">
    Total Unusual Items Excluding Goodwill
   </div>
  </div>
  <div class="column yf-1xjz32c alt">
   -50,000.00
  </div>
  <div class="column yf-1xjz32c">
   -205,000.00
  </div>
  <div class="column yf-1xjz32c alt">
   -7,639,000.00
  </div>
  <div class="column yf-1xjz32c">
   7,457,000.00
  </div>
  <div class="column yf-1xjz32c alt">
   324,000.00
  </div>
  <div class="column yf-1xjz32c">
   --
  </div>
 </div>
 <div class="row lv-0 yf-1xjz32c">
  <div class="column sticky yf-1xjz32c">
   <div class="rowTitle yf-1xjz32c" title="Total Unusual Items">
    Total Unusual Items
   </div>
  </div>
  <div class="column yf-1xjz32c alt">
   -50,000.00
  </div>
  <div class="column yf-1xjz32c">
   -205,000.00
  </div>
  <div class="column yf-1xjz32c alt">
   -7,639,000.00
  </div>
  <div class="column yf-1xjz32c">
   7,457,000.00
  </div>
  <div class="column yf-1xjz32c alt">
   324,000.00
  </div>
  <div class="column yf-1xjz32c">
   --
  </div>
 </div>
 <div class="row lv-0 yf-1xjz32c">
  <div class="column sticky yf-1xjz32c">
   <div class="rowTitle yf-1xjz32c" title="Normalized EBITDA">
    Normalized EBITDA
   </div>
  </div>
  <div class="column yf-1xjz32c alt">
   11,216,000.00
  </div>
  <div class="column yf-1xjz32c">
   12,013,000.00
  </div>
  <div class="column yf-1xjz32c alt">
   12,398,000.00
  </div>
  <div class="column yf-1xjz32c">
   18,086,000.00
  </div>
  <div class="column yf-1xjz32c alt">
   7,668,000.00
  </div>
  <div class="column yf-1xjz32c">
   --
  </div>
 </div>
 <div class="row lv-0 yf-1xjz32c">
  <div class="column sticky yf-1xjz32c">
   <div class="rowTitle yf-1xjz32c" title="Tax Rate for Calcs">
    Tax Rate for Calcs
   </div>
  </div>
  <div class="column yf-1xjz32c alt">
   0.00
  </div>
  <div class="column yf-1xjz32c">
   0.00
  </div>
  <div class="column yf-1xjz32c alt">
   0.00
  </div>
  <div class="column yf-1xjz32c">
   0.00
  </div>
  <div class="column yf-1xjz32c alt">
   0.00
  </div>
  <div class="column yf-1xjz32c">
   --
  </div>
 </div>
 <div class="row lv-0 yf-1xjz32c">
  <div class="column sticky yf-1xjz32c">
   <div class="rowTitle yf-1xjz32c" title="Tax Effect of Unusual Items">
    Tax Effect of Unusual Items
   </div>
  </div>
  <div class="column yf-1xjz32c alt">
   -10,500.00
  </div>
  <div class="column yf-1xjz32c">
   -43,050.00
  </div>
  <div class="column yf-1xjz32c alt">
   -2,184,754.00
  </div>
  <div class="column yf-1xjz32c">
   2,013,390.00
  </div>
  <div class="column yf-1xjz32c alt">
   87,480.00
  </div>
  <div class="column yf-1xjz32c">
   --
  </div>
 </div>
</div>


'''

# Sử dụng BeautifulSoup để phân tích HTML
soup = BeautifulSoup(html_content, 'html.parser')

# Lấy tên hàng đầu tiên, ví dụ: Total Revenue
row_title = soup.find('div', class_='rowTitle').get_text(strip=True)

# Lấy các giá trị doanh thu tương ứng
columns = soup.find_all('div', class_='column yf-1xjz32c')
revenues = [col.get_text(strip=True) for col in columns]

# Lấy các năm từ cột (ví dụ là các năm giả định)
years = ['TTM', '12/31/2023', '12/31/2021', '12/31/2019']

# Tạo từ điển kết quả
summary = {year: revenue for year, revenue in zip(years, revenues)}

# In kết quả
print(f'{row_title}:')
for year, revenue in summary.items():
    print(f'{year}: {revenue}')
# Out:
# Total Revenue:
# TTM: 176,191,000.00
# 12/31/2023: 136,341,000.00
# 12/31/2021: --
# 12/31/2019: 160,031,000.00
